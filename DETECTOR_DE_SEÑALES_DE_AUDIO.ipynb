# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseEmiliano12/ESTRUCTURA-DE-DATOS-Proyecto/blob/master/DETECTOR_DE_SE%C3%91ALES_DE_AUDIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Objetvios Del Proyecto:
# General: Desarrollar un sistema de detección y clasificación de señales de audio marcadas digitalmente.
#
# Específicos:
#
#     Obtener un corpus de señales de audio marcadas mediante diferentes técnicas de marcado clásico y profundo.
#     Determinar un dominio de operación adecuado para la detección de marcado digital.
#     Determinar un modelo de clasificación de señales marcadas y sin marcar.
